# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_html("/content/drive/MyDrive/KnowledgeHut UpGrad/KH_BootCamp 2023 06/Datasets/Veggie_Price_Data.html")[3]
df
# Out:
#              Date     Market  Arrival(q) Price Minimum (Rs/q)  \
# 0     01/Jan/2005  BANGALORE        6823                  440
# 1     03/Jan/2005  BANGALORE        5046                  400
# 2     05/Jan/2005  BANGALORE        6413                  420
# 3     06/Jan/2005  BANGALORE        7496                  440
# 4     07/Jan/2005  BANGALORE        9625                  410
# ...           ...        ...         ...                  ...
# 4184  08/Jul/2022  BANGALORE       10550                 2600
# 4185  11/Jul/2022  BANGALORE       15870                 2600
# 4186  14/Sep/2022  BANGALORE        9220                 1600
# 4187  17/Sep/2022  BANGALORE       13200                 1600
# 4188          NaN      Total    41438323             955(Avg)
#
#      Price Maximum (Rs/q) Modal Price (Rs/q)
# 0                     580                510
# 1                     560                500
# 2                     560                500
# ...

# %%
df=df[["Date","Modal Price (Rs/q)"]]
df
# Out:
#              Date Modal Price (Rs/q)
# 0     01/Jan/2005                510
# 1     03/Jan/2005                500
# 2     05/Jan/2005                500
# 3     06/Jan/2005                500
# 4     07/Jan/2005                425
# ...           ...                ...
# 4184  08/Jul/2022               2700
# 4185  11/Jul/2022               2700
# 4186  14/Sep/2022               1800
# 4187  17/Sep/2022               1800
# 4188          NaN          1189(Avg)
#
# [4189 rows x 2 columns]

# %%
df.rename(columns={'Modal Price (Rs/q)':'Price'},inplace=True)
# Out:
# <ipython-input-118-72acf49cb7b6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Modal Price (Rs/q)':'Price'},inplace=True)

# %%
df
# Out:
#              Date      Price
# 0     01/Jan/2005        510
# 1     03/Jan/2005        500
# 2     05/Jan/2005        500
# 3     06/Jan/2005        500
# 4     07/Jan/2005        425
# ...           ...        ...
# 4184  08/Jul/2022       2700
# 4185  11/Jul/2022       2700
# 4186  14/Sep/2022       1800
# 4187  17/Sep/2022       1800
# 4188          NaN  1189(Avg)
#
# [4189 rows x 2 columns]

# %%
df.duplicated().sum()
# Out:
# 5

# %%
df[df.duplicated()]
# Out:
#              Date Price
# 3778  03/Jun/2019  1410
# 3779  03/Jun/2019  1410
# 3788  14/Jun/2019  1400
# 3823  02/Aug/2019  1050
# 3826  05/Aug/2019  1050

# %%
df.drop_duplicates(ignore_index=True,inplace=True)
# Out:
# <ipython-input-122-ef2655c3b219>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(ignore_index=True,inplace=True)

# %%
df
# Out:
#              Date      Price
# 0     01/Jan/2005        510
# 1     03/Jan/2005        500
# 2     05/Jan/2005        500
# 3     06/Jan/2005        500
# 4     07/Jan/2005        425
# ...           ...        ...
# 4179  08/Jul/2022       2700
# 4180  11/Jul/2022       2700
# 4181  14/Sep/2022       1800
# 4182  17/Sep/2022       1800
# 4183          NaN  1189(Avg)
#
# [4184 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Date     1
# Price    0
# dtype: int64

# %%
df.dropna(inplace=True)
# Out:
# <ipython-input-125-c64f9f573c18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df
# Out:
#              Date Price
# 0     01/Jan/2005   510
# 1     03/Jan/2005   500
# 2     05/Jan/2005   500
# 3     06/Jan/2005   500
# 4     07/Jan/2005   425
# ...           ...   ...
# 4178  04/Jun/2022  2400
# 4179  08/Jul/2022  2700
# 4180  11/Jul/2022  2700
# 4181  14/Sep/2022  1800
# 4182  17/Sep/2022  1800
#
# [4183 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Date     0
# Price    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4183 entries, 0 to 4182
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    4183 non-null   object
#  1   Price   4183 non-null   object
# dtypes: object(2)
# memory usage: 98.0+ KB

# %%
# https://pbpython.com/pandas_dtypes.html

# %%
# FBProphet

# %%
df.rename(columns={'Price':'y','Date':'ds'},inplace=True)
# Out:
# <ipython-input-131-99fe41e1d361>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Price':'y','Date':'ds'},inplace=True)

# %%
df
# Out:
#                ds     y
# 0     01/Jan/2005   510
# 1     03/Jan/2005   500
# 2     05/Jan/2005   500
# 3     06/Jan/2005   500
# 4     07/Jan/2005   425
# ...           ...   ...
# 4178  04/Jun/2022  2400
# 4179  08/Jul/2022  2700
# 4180  11/Jul/2022  2700
# 4181  14/Sep/2022  1800
# 4182  17/Sep/2022  1800
#
# [4183 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4183 entries, 0 to 4182
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      4183 non-null   object
#  1   y       4183 non-null   object
# dtypes: object(2)
# memory usage: 98.0+ KB

# %%
df['ds']=pd.to_datetime(df['ds'])
# Out:
# <ipython-input-134-9ea62d8e935b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ds']=pd.to_datetime(df['ds'])

# %%
df['y']=df['y'].astype('int')
# Out:
# <ipython-input-135-4225cc58fec9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['y']=df['y'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4183 entries, 0 to 4182
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      4183 non-null   datetime64[ns]
#  1   y       4183 non-null   int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 98.0 KB

# %%
df.head(3)
# Out:
#           ds    y
# 0 2005-01-01  510
# 1 2005-01-03  500
# 2 2005-01-05  500

# %%
plt.figure(figsize=(22,8))
plt.scatter(df['ds'],df['y'])
plt.grid(linestyle='--')

# %%
df[df['y']>2900]
# Out:
#              ds     y
# 4040 2020-10-28  3300
# 4041 2020-10-29  3000
# 4042 2020-11-02  3400
# 4043 2020-11-03  3300
# 4044 2020-11-05  3300
# 4045 2020-11-06  3300
# 4047 2020-11-12  3200
# 4048 2020-11-25  3200
# 4049 2020-12-05  3550
# 4050 2020-12-08  3250

# %%
np.where(df['y']>2900)
# Out:
# (array([4040, 4041, 4042, 4043, 4044, 4045, 4047, 4048, 4049, 4050]),)

# %%
df['y']=np.where(df['y']>2900,np.nan,df['y'])
# Out:
# <ipython-input-141-a4d834171391>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['y']=np.where(df['y']>2900,np.nan,df['y'])

# %%
df[df['y']>2900]
# Out:
# Empty DataFrame
# Columns: [ds, y]
# Index: []

# %%
df.isnull().sum()
# Out:
# ds     0
# y     10
# dtype: int64

# %%
df.dropna(inplace=True)
# Out:
# <ipython-input-144-c64f9f573c18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# ds    0
# y     0
# dtype: int64

# %%
plt.figure(figsize=(22,8))
plt.scatter(df['ds'],df['y'])
plt.grid(linestyle='--')

# %%
from prophet import Prophet

# %%
op=Prophet()

# %%
op.fit(df)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnwdgu93r/pc3533c7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnwdgu93r/qx5ila43.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38577', 'data', 'file=/tmp/tmpnwdgu93r/pc3533c7.json', 'init=/tmp/tmpnwdgu93r/qx5ila43.json', 'output', 'file=/tmp/tmpnwdgu93r/prophet_model1et_2hcc/prophet_model-20231217094649.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:46:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:46:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
forecast=op.make_future_dataframe(periods=700,freq="D")

# %%
forecast
# Out:
#              ds
# 0    2005-01-01
# 1    2005-01-03
# 2    2005-01-05
# 3    2005-01-06
# 4    2005-01-07
# ...         ...
# 4867 2024-08-13
# 4868 2024-08-14
# 4869 2024-08-15
# 4870 2024-08-16
# 4871 2024-08-17
#
# [4872 rows x 1 columns]

# %%
forecast=op.predict(forecast)
forecast
# Out:
#              ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0    2005-01-01   699.151600   371.537114  1182.688082   699.151600
# 1    2005-01-03   699.694117   368.570894  1169.866787   699.694117
# 2    2005-01-05   700.236634   366.519160  1161.862697   700.236634
# 3    2005-01-06   700.507892   384.280717  1221.402758   700.507892
# 4    2005-01-07   700.779151   369.026766  1175.000153   700.779151
# ...         ...          ...          ...          ...          ...
# 4867 2024-08-13  2000.247834  1544.821818  2417.308228  1830.910406
# 4868 2024-08-14  2000.563015  1552.170906  2434.183772  1830.316665
# 4869 2024-08-15  2000.878196  1543.510763  2452.710398  1830.174199
# 4870 2024-08-16  2001.193376  1564.673299  2402.603346  1830.093647
# 4871 2024-08-17  2001.508557  1508.562456  2399.962806  1829.834992
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# ...

# %%
op.plot(forecast,xlabel='Date',ylabel='Potato price/q',figsize=(20,8),include_legend=True)

# %%
from prophet.plot import plot_plotly, plot_components_plotly
plot_plotly(op, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_components_plotly(op, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
